# %%
import numpy as np
import pandas as pd
from scipy import sparse
import seaborn as sns
from collections import defaultdict
import logging
logging.basicConfig()

from diamond.glms.logistic import LogisticRegression

# %matplotlib inline

# %% [markdown]
# This dataset is from the UCI Machine Learning Repository https://archive.ics.uci.edu/ml/datasets/Soybean+(Small)
#
# Origin:
#
# Michalski,R.S.
# Learning by being told and learning from examples: an experimental comparison of the two methodes of knowledge acquisition in the context of developing an expert system for soybean desease diagnoiss",
# International Journal of Policy Analysis and Information Systems, 1980, 4(2), 125-161.
#
# The example here is not intended to be statistically useful, but rather just to show the nuts and bolts of fitting a model using Diamond.

# %% [markdown]
# # Load the data and the covariance structure

# %%
df = pd.read_csv('soybean_small.csv')
df.head()
# Out:
#    date  plant_stand  precip  temp  hail  crop_hist  area_damaged  severity  \
# 0     4            0       2     1     1          1             0         1
# 1     5            0       2     1     0          3             1         1
# 2     3            0       2     1     0          2             0         2
# 3     6            0       2     1     0          1             1         1
# 4     4            0       2     1     0          3             0         2
#
#    seed_tmt  germination ...  sclerotia  fruit_pods  fruit spots  seed  \
# 0         0            2 ...          0           0            4     0
# 1         1            2 ...          0           0            4     0
# 2         1            1 ...          0           0            4     0
# 3         0            0 ...          0           0            4     0
# 4         0            2 ...          0           0            4     0
#
#    mold_growth  seed_discolor  seed_size  shriveling  roots  NA
# 0            0              0          0           0      0  D1
# 1            0              0          0           0      0  D1
# 2            0              0          0           0      0  D1
# 3            0              0          0           0      0  D1
# 4            0              0          0           0      0  D1
#
# [5 rows x 36 columns]

# %% [markdown]
# Note that the covariance structure, here referred to as the priors, is only for the random effect components. The fixed effects are not regularized in Diamond. The priors data frame has the following columns:
#   - grp: the grouping factor (in this case "leaves") that the variables belong to
#   - var1: variable in the model which belongs to group factor `grp`
#   - var2: same as var1. Set to NaN to denote the variance of var1
#   - vcov: (co)variance between var1 and var2
#   - sdcor: square root of vcov (optional - not used in Diamond)

# %%
priors = pd.read_csv("soybean_small_priors.csv")
priors.head()
# Out:
#     group       var1  var2      vcov     sdcor
# 0  leaves  intercept   NaN  0.012599  0.112246
# 1  leaves     precip   NaN  0.049492  0.222468

# %% [markdown]
# # Fit the model

# %%
model = LogisticRegression(df, priors)

# %%
formula = 'fruiting_bodies ~ 1 + precip + (1 + precip | leaves)'

# %%
effects = model.fit(formula, tol=1e-4, verbose=True)
# Out:
# INFO:diamond.glms.glm:creating main design matrix
# INFO:diamond.glms.glm:creating leaves design matrix
# INFO:diamond.glms.glm:creating covariance matrix
# INFO:diamond.glms.logistic:creating Hessians
# INFO:diamond.glms.logistic:creating H_inter for leaves
# INFO:diamond.glms.logistic:time elapsed: 0.0
# INFO:diamond.glms.logistic:blocks inverted: 0 of 2
# INFO:diamond.glms.logistic:creating H_invs
# /Users/tsweetser/.virtualenvs/stitch/lib/python2.7/site-packages/diamond/solvers/diamond_logistic.py:73: RuntimeWarning: invalid value encountered in double_scalars
#   np.linalg.norm(effects[grouping])
# INFO:diamond.solvers.diamond_logistic:loss: 477.033641 penalty: 1.901035 seconds elapsed 0
# INFO:diamond.solvers.diamond_logistic:iteration: 0 relative coef change: 1.000000 obj: 478.934676
# INFO:diamond.solvers.diamond_logistic:loss: 472.582817 penalty: 1.320383 seconds elapsed 0
# INFO:diamond.solvers.diamond_logistic:iteration: 1 relative coef change: 0.356817 obj: 473.903200
# INFO:diamond.solvers.diamond_logistic:loss: 469.269012 penalty: 1.155364 seconds elapsed 0
# INFO:diamond.solvers.diamond_logistic:iteration:
seconds elapsed 0
# INFO:diamond.solvers.diamond_logistic:iteration: 27 relative coef change: 0.014995 obj: 630.600968
# INFO:diamond.solvers.diamond_logistic:loss: 630.904707 penalty: 1.326015 seconds elapsed 0
# INFO:diamond.solvers.diamond_logistic:iteration: 28 relative coef change: 0.005792 obj: 632.230722
# INFO:diamond.solvers.diamond_logistic:loss: 639.151499 penalty: 1.327024 seconds elapsed 0
# INFO:diamond.solvers.diamond_logistic:iteration: 29 relative coef change: 0.028848 obj: 640.478523
# INFO:diamond.solvers.diamond_logistic:loss: 640.551374 penalty: 1.327848 seconds elapsed 0
# INFO:diamond.solvers.diamond_logistic:iteration: 30 relative coef change: 0.004758 obj: 641.879222
# INFO:diamond.solvers.diamond_logistic:loss: 643.242112 penalty: 1.328578 seconds elapsed 0
# INFO:diamond.solvers.diamond_logistic:iteration: 31 relative coef change: 0.009299 obj: 644.570690
# INFO:diamond.solvers.diamond_logistic:loss: 645.234062 penalty: 1.329192 seconds elapsed 0
# INFO:diamond.solvers.diamond_logistic:iteration: 32 relative coef change: 0.006703 obj: 646.563254
# INFO:diamond.solvers.diamond_logistic:loss: 645.420579 penalty: 1.329735 seconds elapsed 0
# INFO:diamond.solvers.diamond_logistic:iteration: 33 relative coef change: 0.001129 obj: 646.750314
# INFO:diamond.solvers.diamond_logistic:loss: 646.872822 penalty: 1.330113 seconds elapsed 0
# INFO:diamond.solvers.diamond_logistic:iteration: 34 relative coef change: 0.004585 obj: 648.202935
# INFO:diamond.solvers.diamond_logistic:loss: 647.032188 penalty: 1.330503 seconds elapsed 0
# INFO:diamond.solvers.diamond_logistic:iteration: 35 relative coef change: 0.000888 obj: 648.362691
# INFO:diamond.solvers.diamond_logistic:loss: 671.156123 penalty: 1.330773 seconds elapsed 0
# INFO:diamond.solvers.diamond_logistic:iteration: 36 relative coef change: 0.074962 obj: 672.486897
# INFO:diamond.solvers.diamond_logistic:loss: 673.952978 penalty: 1.331054 seconds elapsed 0
# INFO:diamond.solvers.diamond_logistic:iteration: 37 relative coef change: 0.009109 obj: 675.284032
# INFO:diamond.solvers.diamond_logistic:loss: 674.087890 penalty: 1.331199 seconds elapsed 0
# INFO:diamond.solvers.diamond_logistic:iteration: 38 relative coef change: 0.000160 obj: 675.419089
# INFO:diamond.solvers.diamond_logistic:loss: 675.429319 penalty: 1.331404 seconds elapsed 0
# INFO:diamond.solvers.diamond_logistic:iteration: 39 relative coef change: 0.004021 obj: 676.760723
# INFO:diamond.solvers.diamond_logistic:loss: 675.379735 penalty: 1.331604 seconds elapsed 0
# INFO:diamond.solvers.diamond_logistic:iteration: 40 relative coef change: 0.000210 obj: 676.711340
# INFO:diamond.solvers.diamond_logistic:loss: 676.699315 penalty: 1.331745 seconds elapsed 0
# INFO:diamond.solvers.diamond_logistic:iteration: 41 relative coef change: 0.004280 obj: 678.031060
# INFO:diamond.solvers.diamond_logistic:loss: 676.894417 penalty: 1.331816 seconds elapsed 0
# INFO:diamond.solvers.diamond_logistic:iteration: 42 relative coef change: 0.000330 obj: 678.226233
# INFO:diamond.solvers.diamond_logistic:loss: 676.913700 penalty: 1.331936 seconds elapsed 0
# INFO:diamond.solvers.diamond_logistic:iteration: 43 relative coef change: 0.000151 obj: 678.245636
# INFO:diamond.solvers.diamond_logistic:loss: 678.563069 penalty: 1.332019 seconds elapsed 0
# INFO:diamond.solvers.diamond_logistic:iteration: 44 relative coef change: 0.005238 obj: 679.895089
# INFO:diamond.solvers.diamond_logistic:loss: 678.756947 penalty: 1.332047 seconds elapsed 0
# INFO:diamond.solvers.diamond_logistic:iteration: 45 relative coef change: 0.000305 obj: 680.088993
# INFO:diamond.solvers.diamond_logistic:loss: 678.743047 penalty: 1.332131 seconds elapsed 0
# INFO:diamond.solvers.diamond_logistic:iteration: 46 relative coef change: 0.000088 obj: 680.075178
# INFO:diamond.solvers.diamond_logistic:total seconds elapsed: 0
# INFO:diamond.solvers.diamond_logistic:reached convergence after 46 steps. relative coef change: 0.000088
# INFO:diamond.glms.logistic:extracting coefficients

# %% [markdown]
# # Combine random and fixed effects

# %%
results = model.results_dict['leaves'].copy()

# %%
for var in model.results_dict["fixed_effects"].variable.unique():
    if var in results.columns:
        results[var] = (results[var] + 
            model.results_dict['fixed_effects'][model.results_dict['fixed_effects'].variable == var].value.values[0])
    else:
        results[var] = (
            model.results_dict['fixed_effects'][model.results_dict['fixed_effects'].variable == var].value.values[0])

# %%
results
# Out:
#    leaves  intercept     precip
# 0       0 -27.603985  13.101506
# 1       1 -27.559170  13.453600
