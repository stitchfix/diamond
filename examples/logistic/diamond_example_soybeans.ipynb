# %%
import numpy as np
import pandas as pd
from scipy import sparse
import seaborn as sns
from collections import defaultdict
import logging
logging.basicConfig()

from diamond.glms.logistic import LogisticRegression

# %matplotlib inline

# %% [markdown]
# This dataset is from the UCI Machine Learning Repository https://archive.ics.uci.edu/ml/datasets/Soybean+(Small)
#
# Origin:
#
# Michalski,R.S.
# Learning by being told and learning from examples: an experimental comparison of the two methodes of knowledge acquisition in the context of developing an expert system for soybean desease diagnoiss",
# International Journal of Policy Analysis and Information Systems, 1980, 4(2), 125-161.
#
# The example here is not intended to be statistically useful, but rather just to show the nuts and bolts of fitting a model using Diamond.

# %% [markdown]
# # Load the data and the covariance structure

# %%
df = pd.read_csv('soybean_small.csv')
df.head()
# Out:
#    date  plant_stand  precip  temp  hail  crop_hist  area_damaged  severity  \
# 0     4            0       2     1     1          1             0         1
# 1     5            0       2     1     0          3             1         1
# 2     3            0       2     1     0          2             0         2
# 3     6            0       2     1     0          1             1         1
# 4     4            0       2     1     0          3             0         2
#
#    seed_tmt  germination ...  sclerotia  fruit_pods  fruit spots  seed  \
# 0         0            2 ...          0           0            4     0
# 1         1            2 ...          0           0            4     0
# 2         1            1 ...          0           0            4     0
# 3         0            0 ...          0           0            4     0
# 4         0            2 ...          0           0            4     0
#
#    mold_growth  seed_discolor  seed_size  shriveling  roots  NA
# 0            0              0          0           0      0  D1
# 1            0              0          0           0      0  D1
# 2            0              0          0           0      0  D1
# 3            0              0          0           0      0  D1
# 4            0              0          0           0      0  D1
#
# [5 rows x 36 columns]

# %% [markdown]
# Note that the covariance structure, here referred to as the priors, is only for the random effect components. The fixed effects are not regularized in Diamond. The priors data frame has the following columns:
#   - grp: the grouping factor (in this case "leaves") that the variables belong to
#   - var1: variable in the model which belongs to group factor `grp`
#   - var2: same as var1. Set to NaN to denote the variance of var1
#   - vcov: (co)variance between var1 and var2
#   - sdcor: square root of vcov (optional - not used in Diamond)

# %%
priors = pd.read_csv("soybean_small_priors.csv")
priors.head()
# Out:
#       grp       var1  var2      vcov     sdcor
# 0  leaves  intercept   NaN  0.012599  0.112246
# 1  leaves     precip   NaN  0.049492  0.222468

# %% [markdown]
# # Fit the model

# %%
model = LogisticRegression(df, priors)

# %%
formula = 'fruiting_bodies ~ 1 + precip + (1 + precip | leaves)'

# %%
effects = model.fit(formula, tol=1e-4, verbose=True)
# Out:
# INFO:diamond:creating main design matrix
# INFO:diamond:creating leaves design matrix
# INFO:diamond:creating covariance matrix
# INFO:diamond:creating Hessians
# INFO:diamond:creating H_inter for leaves
# INFO:diamond:time elapsed: 0.0
# INFO:diamond:blocks inverted: 0 of 2
# INFO:diamond:creating H_invs
# loss:  477.033640854
# penalty:  1.90103465679
# seconds elapsed: 0
# iteration:  0 relative coef change:  1.0 obj:  478.934675511
# loss:  471.294137883
# penalty:  1.32038267558
# seconds elapsed: 0
# iteration:  1 relative coef change:  0.356817154498 obj:  472.614520558
# loss:  457.603613099
# penalty:  1.1549274814
# seconds elapsed: 0
# iteration:  2 relative coef change:  0.262887394611 obj:  458.75854058
# loss:  452.700500964
# penalty:  1.12710527809
# seconds elapsed: 0
# iteration:  3 relative coef change:  0.166151724338 obj:  453.827606242
# loss:  450.480230922
# penalty:  1.13544067991
# seconds elapsed: 0
# iteration:  4 relative coef change:  0.101623981243 obj:  451.615671602
# loss:  450.207392221
# penalty:  1.14885106683
# seconds elapsed: 0
# iteration:  5 relative coef change:  0.0580275803276 obj:  451.356243288
# loss:  450.94455974
# penalty:  1.16270077546
# seconds elapsed: 0
# iteration:  6 relative coef change:  0.0420669036814 obj:  452.107260515
# loss:  463.742248907
# penalty:  1.17067949821
# seconds elapsed: 0
# iteration:  7 relative coef change:  0.177245775441 obj:  464.912928406
# loss:  466.00037088
# penalty:  1.17469028665
# seconds elapsed: 0
# iteration:  8 relative coef change:  0.00887117786985 obj:  467.175061167
# loss:  473.640713262
# penalty:  1.17890457381
# seconds elapsed: 0
# iteration:  9 relative coef change:  0.0873367949947 obj:  474.819617835
# loss:  474.521513735
# penalty:  1.18301052498
# seconds elapsed: 0
# iteration:  10 relative coef change:  0.00827416975271 obj:  475.70452426
# loss:  476.27833258
# penalty:  1.18719560795
# seconds elapsed: 0
# iteration:  11 relative coef change:  0.00818641415593 obj:  477.465528188
# loss:  471.845905061
# penalty:  1.1915200559
# seconds elapsed: 0
# iteration:  12 relative coef change:  0.0082251850148 obj:  473.037425117
# loss:  473.839911014
# penalty:  1.19539912968
# seconds elapsed: 0
# iteration:  13 relative coef change:  0.00708168708463 obj:  475.035310144
# loss:  475.021263872
# penalty:  1.1994496034
# seconds elapsed: 0
# iteration:  14 relative coef change:  0.00724662242186 obj:  476.220713476
# loss:  468.812075878
# penalty:  1.2035822251
# seconds elapsed: 0
# iteration:  15 relative coef change:  0.00861363920434 obj:  470.015658103
# loss:  474.103366441
# penalty:  1.20692318147
# seconds elapsed: 0
# iteration:  16 relative coef change:  0.00560006223885 obj:  475.310289622
# loss:  475.179497249
# penalty:  1.21079556696
# seconds elapsed: 0
# iteration:  17 relative coef change:  0.00645309066247 obj:  476.390292816
# loss:  486.770480189
# penalty:  1.21473396094
# seconds elapsed: 0
# iteration:  18 relative coef change:  0.101496932454 obj:  487.98521415
# loss:  487.045436451
# penalty:  1.21848364221
# seconds elapsed: 0
# iteration:  19 relative coef change:  0.00589460678457 obj:  488.263920094
# loss:  487.137029904
# penalty:  1.2222086739
# seconds elapsed: 0
# iteration:  20 relative coef change:  0.00575501312651 obj:  488.359238577
# loss:  487.299776004
# penalty:  1.22588278427
# seconds elapsed: 0
# iteration:  21 relative coef change:  0.0055796399162 obj:  488.525658788
# loss:  488.179113015
# penalty:  1.22950926388
# seconds elapsed: 0
# iteration:  22 relative coef change:  0.00541742304163 obj:  489.408622279
# loss:  485.608684096
# penalty:  1.23316004873
# seconds elapsed: 0
# iteration:  23 relative coef change:  0.00537090262007 obj:  486.841844145
# loss:  486.582005734
# penalty:  1.23640691886
# seconds elapsed: 0
# iteration:  24 relative coef change:  0.00468782036923 obj:  487.818412653
# loss:  486.881645353
# penalty:  1.23971333974
# seconds elapsed: 0
# iteration:  25 relative coef change:  0.00471662960055 obj:  488.121358692
# loss:  487.691374593
# penalty:  1.24298637862
# seconds elapsed: 0
# iteration:  26 relative coef change:  0.00460827396832 obj:  488.934360972
# loss:  485.275897243
# penalty:  1.24628047948
# seconds elapsed: 0
# iteration:  27 relative coef change:  0.00457956581908 obj:  486.522177723
# loss:  486.401933669
# penalty:  1.24916157859
# seconds elapsed: 0
# iteration:  28 relative coef change:  0.00394853917714 obj:  487.651095248
# loss:  486.864851458
# penalty:  1.25212945719
# seconds elapsed: 0
# iteration:  29 relative coef change:  0.00402674218391 obj:  488.116980915
# loss:  488.808034485
# penalty:  1.2550851876
# seconds elapsed: 0
# iteration:  30 relative coef change:  0.0214965485948 obj:  490.063119673
# loss:  489.231390416
# penalty:  1.25784265847
# seconds elapsed: 0
# iteration:  31 relative coef change:  0.00364909435796 obj:  490.489233075
# loss:  489.855298029
# penalty:  1.2605886637
# seconds elapsed: 0
# iteration:  32 relative coef change:  0.00359934133387 obj:  491.115886692
# loss:  487.681629755
# penalty:  1.26334276441
# seconds elapsed: 0
# iteration:  33 relative coef change:  0.00357529941854 obj:  488.944972519
# loss:  488.971237276
# penalty:  1.26568789989
# seconds elapsed: 0
# iteration:  34 relative coef change:  0.00301767572108 obj:  490.236925176
# loss:  489.478297039
# penalty:  1.26816008289
# seconds elapsed: 0
# iteration:  35 relative coef change:  0.00315516968323 obj:  490.746457121
# loss:  490.436746243
# penalty:  1.27063386223
# seconds elapsed: 0
# iteration:  36 relative coef change:  0.012533208398 obj:  491.707380105
# loss:  490.88010203
# penalty:  1.2729297522
# seconds elapsed: 0
# iteration:  37 relative coef change:  0.00287797270453 obj:  492.153031782
# loss:  491.79438212
# penalty:  1.27522383674
# seconds elapsed: 0
# iteration:  38 relative coef change:  0.011517917322 obj:  493.069605957
# loss:  492.235179942
# penalty:  1.27735178214
# seconds elapsed: 0
# iteration:  39 relative coef change:  0.00262514653164 obj:  493.512531724
# loss:  493.920224656
# penalty:  1.27948285782
# seconds elapsed: 0
# iteration:  40 relative coef change:  0.0026106733568 obj:  495.199707514
# loss:  491.820101321
# penalty:  1.28176933116
# seconds elapsed: 0
# iteration:  41 relative coef change:  0.00277661614579 obj:  493.101870652
# loss:  492.349397134
# penalty:  1.28365232362
# seconds elapsed: 0
# iteration:  42 relative coef change:  0.00227889454111 obj:  493.633049458
# loss:  494.426712611
# penalty:  1.28555949895
# seconds elapsed: 0
# iteration:  43 relative coef change:  0.00279743517017 obj:  495.71227211
# loss:  492.127113012
# penalty:  1.28768003711
# seconds elapsed: 0
# iteration:  44 relative coef change:  0.00252534095949 obj:  493.414793049
# loss:  492.673159175
# penalty:  1.28936038147
# seconds elapsed: 0
# iteration:  45 relative coef change:  0.00199957655263 obj:  493.962519556
# loss:  506.769023587
# penalty:  1.29107320338
# seconds elapsed: 0
# iteration:  46 relative coef change:  0.094720545968 obj:  508.06009679
# loss:  506.927911059
# penalty:  1.29266905116
# seconds elapsed: 0
# iteration:  47 relative coef change:  0.00184914463157 obj:  508.22058011
# loss:  507.053569297
# penalty:  1.2942394937
# seconds elapsed: 0
# iteration:  48 relative coef change:  0.00181238010875 obj:  508.347808791
# loss:  508.004785875
# penalty:  1.29577754057
# seconds elapsed: 0
# iteration:  49 relative coef change:  0.00176801736514 obj:  509.300563416
# loss:  506.772050337
# penalty:  1.29739119528
# seconds elapsed: 0
# iteration:  50 relative coef change:  0.00184464117962 obj:  508.069441532
# loss:  506.997903008
# penalty:  1.29874478839
# seconds elapsed: 0
# iteration:  51 relative coef change:  0.00154673510351 obj:  508.296647796
# loss:  507.242784479
# penalty:  1.30009096735
# seconds elapsed: 0
# iteration:  52 relative coef change:  0.00153234766823 obj:  508.542875446
# loss:  506.146578282
# penalty:  1.30142901211
# seconds elapsed: 0
# iteration:  53 relative coef change:  0.00151715752365 obj:  507.448007294
# loss:  506.940657173
# penalty:  1.30252007223
# seconds elapsed: 0
# iteration:  54 relative coef change:  0.00123970357323 obj:  508.243177246
# loss:  507.167122802
# penalty:  1.30370959572
# seconds elapsed: 0
# iteration:  55 relative coef change:  0.00134296765508 obj:  508.470832397
# loss:  505.428555713
# penalty:  1.30489462255
# seconds elapsed: 0
# iteration:  56 relative coef change:  0.00994720376201 obj:  506.733450336
# loss:  508.372121345
# penalty:  1.30548046732
# seconds elapsed: 0
# iteration:  57 relative coef change:  0.000674410446945 obj:  509.677601812
# loss:  508.587476151
# penalty:  1.3065532695
# seconds elapsed: 0
# iteration:  58 relative coef change:  0.00120056594547 obj:  509.894029421
# loss:  513.730201952
# penalty:  1.30762398777
# seconds elapsed: 0
# iteration:  59 relative coef change:  0.0335369574192 obj:  515.03782594
# loss:  513.877081131
# penalty:  1.30861229488
# seconds elapsed: 0
# iteration:  60 relative coef change:  0.00109487843205 obj:  515.185693426
# loss:  514.203002192
# penalty:  1.30959074481
# seconds elapsed: 0
# iteration:  61 relative coef change:  0.00108106662883 obj:  515.512592937
# loss:  513.572273402
# penalty:  1.31058369991
# seconds elapsed: 0
# iteration:  62 relative coef change:  0.00109322688992 obj:  514.882857102
# loss:  513.822799455
# penalty:  1.31143010163
# seconds elapsed: 0
# iteration:  63 relative coef change:  0.00093414580893 obj:  515.134229557
# loss:  514.096752553
# penalty:  1.31228999931
# seconds elapsed: 0
# iteration:  64 relative coef change:  0.000945713548568 obj:  515.409042553
# loss:  513.50306425
# penalty:  1.31316211153
# seconds elapsed: 0
# iteration:  65 relative coef change:  0.000955791863143 obj:  514.816226362
# loss:  513.80742736
# penalty:  1.3138962386
# seconds elapsed: 0
# iteration:  66 relative coef change:  0.000807558346583 obj:  515.121323599
# loss:  514.164837792
# penalty:  1.3146573402
# seconds elapsed: 0
# iteration:  67 relative coef change:  0.000833550985289 obj:  515.479495132
# loss:  513.582927291
# penalty:  1.31544691727
# seconds elapsed: 0
# iteration:  68 relative coef change:  0.000860917894393 obj:  514.898374208
# loss:  513.842760873
# penalty:  1.31610350873
# seconds elapsed: 0
# iteration:  69 relative coef change:  0.000719373600606 obj:  515.158864382
# loss:  514.871689956
# penalty:  1.31678168226
# seconds elapsed: 0
# iteration:  70 relative coef change:  0.00127544378431 obj:  516.188471638
# loss:  513.857061197
# penalty:  1.31758140919
# seconds elapsed: 0
# iteration:  71 relative coef change:  0.000863840529352 obj:  515.174642606
# loss:  514.095588011
# penalty:  1.31817013706
# seconds elapsed: 0
# iteration:  72 relative coef change:  0.000642479604873 obj:  515.413758148
# loss:  513.339102153
# penalty:  1.31877814209
# seconds elapsed: 0
# iteration:  73 relative coef change:  0.000670455798793 obj:  514.657880296
# loss:  514.030263804
# penalty:  1.31921100618
# seconds elapsed: 0
# iteration:  74 relative coef change:  0.000477261832996 obj:  515.34947481
# loss:  514.467132211
# penalty:  1.31975162661
# seconds elapsed: 0
# iteration:  75 relative coef change:  0.000587076074031 obj:  515.786883838
# loss:  513.903796829
# penalty:  1.32034213722
# seconds elapsed: 0
# iteration:  76 relative coef change:  0.000636763361034 obj:  515.224138967
# loss:  514.173502446
# penalty:  1.32080833722
# seconds elapsed: 0
# iteration:  77 relative coef change:  0.00050716234551 obj:  515.494310783
# loss:  513.377114175
# penalty:  1.32130435436
# seconds elapsed: 0
# iteration:  78 relative coef change:  0.000914580999922 obj:  514.698418529
# loss:  514.183717766
# penalty:  1.32161367704
# seconds elapsed: 0
# iteration:  79 relative coef change:  0.000342901567187 obj:  515.505331443
# loss:  514.76986365
# penalty:  1.32205672009
# seconds elapsed: 0
# iteration:  80 relative coef change:  0.000478812661453 obj:  516.09192037
# loss:  514.127995112
# penalty:  1.32257550759
# seconds elapsed: 0
# iteration:  81 relative coef change:  0.000554857600501 obj:  515.45057062
# loss:  514.417484291
# penalty:  1.32295758304
# seconds elapsed: 0
# iteration:  82 relative coef change:  0.000413911808882 obj:  515.740441874
# loss:  513.92429148
# penalty:  1.32337541878
# seconds elapsed: 0
# iteration:  83 relative coef change:  0.000449164141237 obj:  515.247666899
# loss:  514.319282663
# penalty:  1.32368354886
# seconds elapsed: 0
# iteration:  84 relative coef change:  0.00033612620092 obj:  515.642966212
# loss:  519.54358346
# penalty:  1.32405091686
# seconds elapsed: 0
# iteration:  85 relative coef change:  0.0316155404005 obj:  520.867634377
# loss:  519.839945549
# penalty:  1.32438964815
# seconds elapsed: 0
# iteration:  86 relative coef change:  0.000360367278901 obj:  521.164335197
# loss:  519.450994002
# penalty:  1.32476510278
# seconds elapsed: 0
# iteration:  87 relative coef change:  0.000396952499528 obj:  520.775759105
# loss:  519.686267149
# penalty:  1.32505425324
# seconds elapsed: 0
# iteration:  88 relative coef change:  0.000308778751376 obj:  521.011321402
# loss:  519.181880297
# penalty:  1.32537418367
# seconds elapsed: 0
# iteration:  89 relative coef change:  0.000385537220117 obj:  520.507254481
# loss:  519.662574988
# penalty:  1.32557942999
# seconds elapsed: 0
# iteration:  90 relative coef change:  0.000222461087235 obj:  520.988154418
# loss:  521.003264315
# penalty:  1.32586423873
# seconds elapsed: 0
# iteration:  91 relative coef change:  0.00194408849405 obj:  522.329128554
# loss:  519.917437057
# penalty:  1.32632259526
# seconds elapsed: 0
# iteration:  92 relative coef change:  0.0004766693285 obj:  521.243759652
# loss:  520.231209792
# penalty:  1.32656360368
# seconds elapsed: 0
# iteration:  93 relative coef change:  0.000257050729819 obj:  521.557773395
# loss:  519.861454602
# penalty:  1.32684840463
# seconds elapsed: 0
# iteration:  94 relative coef change:  0.000300609638466 obj:  521.188303006
# loss:  520.10871074
# penalty:  1.3270533816
# seconds elapsed: 0
# iteration:  95 relative coef change:  0.000219645876546 obj:  521.435764121
# loss:  519.746266335
# penalty:  1.32729427101
# seconds elapsed: 0
# iteration:  96 relative coef change:  0.000255250697444 obj:  521.073560606
# loss:
# INFO:diamond:extracting coefficients
#  520.061868644
# penalty:  1.32745581912
# seconds elapsed: 0
# iteration:  97 relative coef change:  0.000174839764281 obj:  521.389324463
# loss:  519.40544099
# penalty:  1.32766829512
# seconds elapsed: 0
# iteration:  98 relative coef change:  0.00105671485457 obj:  520.733109285
# loss:  520.18511945
# penalty:  1.32772164809
# seconds elapsed: 0
# iteration:  99 relative coef change:  6.42162644653e-05 obj:  521.512841098
# total seconds elapsed: 0
# reached convergence after  99  steps. relative coef change:  6.42162644653e-05

# %% [markdown]
# # Combine random and fixed effects

# %%
results = model.results_dict['leaves'].copy()

# %%
for var in model.results_dict["fixed_effects"].variable.unique():
    if var in results.columns:
        results[var] = (results[var] + 
            model.results_dict['fixed_effects'][model.results_dict['fixed_effects'].variable == var].value.values[0])
    else:
        results[var] = (
            model.results_dict['fixed_effects'][model.results_dict['fixed_effects'].variable == var].value.values[0])

# %%
results
# Out:
#    leaves  intercept    precip
# 0       0 -14.371869  6.485837
# 1       1 -14.327154  6.837357
